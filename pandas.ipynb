# %%
import pandas as pd

# %%
df = pd.read_csv("olive.csv")
df.head()
# Out:
#        Unnamed: 0  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
# 3  4.North-Apulia       1     1       966           57      240   7952
# 4  5.North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29
# 3       619         50         78          35
# 4       672         50         80          46

# %%
df[['region', 'area', 'arachidic']][:6] # Select a subset of the columns. Fetch the first 6 rows.
# Out:
#    region  area  arachidic
# 0       1     1         60
# 1       1     1         61
# 2       1     1         63
# 3       1     1         78
# 4       1     1         80
# 5       1     1         70

# %%
df[(df['region'] == 1) & (df['area'] == 3)] # Get rows that have region as 1 and area as 3
# Out:
#            Unnamed: 0  region  area  palmitic  palmitoleic  stearic  oleic  \
# 81    82.South-Apulia       1     3      1454          183      196   7057
# 82    83.South-Apulia       1     3      1347          194      197   7277
# 83    84.South-Apulia       1     3      1364          204      225   6929
# 84    85.South-Apulia       1     3      1410          199      216   7130
# 85    86.South-Apulia       1     3      1384          178      208   7105
# 86    87.South-Apulia       1     3      1412          185      217   6842
# 87    88.South-Apulia       1     3      1410          232      280   6715
# 88    89.South-Apulia       1     3      1509          209      257   6647
# 89    90.South-Apulia       1     3      1317          197      256   7036
# 90    91.South-Apulia       1     3      1286          192      203   7132
# 91    92.South-Apulia       1     3      1273          191      202   6862
# ...

# %%
df_renamed = df.rename(columns={'Unnamed: 0':'Description'}) # Rename a column
df_renamed.head()
# Out:
#       Description  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1      1088           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
# 3  4.North-Apulia       1     1       966           57      240   7952
# 4  5.North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29
# 3       619         50         78          35
# 4       672         50         80          46

# %%
df_renamed['palmitic'][1] = None
df_renamed.head()
# Out:
#       Description  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 1  2.North-Apulia       1     1       NaN           73      224   7709
# 2  3.North-Apulia       1     1       911           54      246   8113
# 3  4.North-Apulia       1     1       966           57      240   7952
# 4  5.North-Apulia       1     1      1051           67      259   7771
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 1       781         31         61          29
# 2       549         31         63          29
# 3       619         50         78          35
# 4       672         50         80          46

# %%
df_renamed.dropna(inplace=True) # Drop null values, in the same DF.
df_renamed.head()
# Out:
#       Description  region  area  palmitic  palmitoleic  stearic  oleic  \
# 0  1.North-Apulia       1     1      1075           75      226   7823
# 2  3.North-Apulia       1     1       911           54      246   8113
# 3  4.North-Apulia       1     1       966           57      240   7952
# 4  5.North-Apulia       1     1      1051           67      259   7771
# 5  6.North-Apulia       1     1       911           49      268   7924
#
#    linoleic  linolenic  arachidic  eicosenoic
# 0       672         36         60          29
# 2       549         31         63          29
# 3       619         50         78          35
# 4       672         50         80          46
# 5       678         51         70          44

# %%
df_renamed.ix[:13,:5] # Subset of the dataframe
# Out:
#    Description  region  area  palmitic  palmitoleic
# 0            5       5     5         5            5
# 2            5       5     5         5            5
# 3            5       5     5         5            5
# 4            5       5     5         5            5
# 6            5       5     5         5            5
# 7            5       5     5         5            5
# 8            5       5     5         5            5
# 9            5       5     5         5            5
# 10           5       5     5         5            5
# 11           5       5     5         5            5
# 12           5       5     5         5            5
# 13           5       5     5         5            5
